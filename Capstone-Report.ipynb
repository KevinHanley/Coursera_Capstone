# %% [markdown]
# # Capstone Report

# %% [markdown]
# ### An Analysis of London vs New York

# %% [markdown]
# #### 1. Introduction
#
# ##### A description of the problem and a discussion of the background.

# %% [markdown]
# For this Capstone project, I will be trying to find the best location for a new business to set up. This fictional company, which I will call “ABC Ltd”, is a trying to decide whether to set up in London (UK) or New York City (USA).
#
# I will leverage Foursquare location data to compare the two cities, and find the best location for this business to locate.
#
# Both cities are financial and economic cores in their respective countries, therefore I hope this analysis will lead to some interesting findings.
#
# The key stakeholders are the business owners, who will be using this analysis to make a crucial business decision.

# %% [markdown]
# #### 2. Data
#
# ##### A description of the data and how it will be used to solve the problem.

# %% [markdown]
# For this analysis, I will be leveraging Foursquare location data primarily.
#
# Additionally, I will scrap several wikipedia pages to identity the neighbourhoods of both cities, and each neighbourhoods respective coordinates.
#
# This will lead to the creation of some data frames, from which I can do an deeper analysis using Foursquare.
