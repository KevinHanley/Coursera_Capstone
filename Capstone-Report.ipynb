# %% [markdown]
# # Capstone Report

# %% [markdown]
# ### An Analysis of London and to set up a business

# %% [markdown]
# #### 1. Introduction
#
# ##### A description of the problem and a discussion of the background.

# %% [markdown]
# For this Capstone project, I will be trying to find the best location for a new business to set up. This fictional company, which I will call “Food Ltd”, is a trying to decide where to set up in London (UK).
#
# I will leverage Foursquare location data to compare the neighbourhoods in the city, and find the best location for this business to locate.
#
# London is the financial and economic centre of the UK, and is similar to NYC and Toronto.
#
# The key stakeholders are the business owners, who will be using this analysis to make a crucial business decision.

# %% [markdown]
# #### 2. Data
#
# ##### A description of the data and how it will be used to solve the problem.

# %% [markdown]
# For this analysis, I will be leveraging Foursquare location data primarily.
#
# Additionally, I will scrap several wikipedia pages to identity the bouroughs of the city, and each bouroughs respective coordinates.
#
# This will lead to the creation of some data frames, from which I can do an deeper analysis using Foursquare.
#
# Data Source:
#
# https://en.wikipedia.org/wiki/List_of_London_boroughs
#
# https://en.wikipedia.org/wiki/List_of_areas_of_London
